# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# pip install citipy

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 751

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data2 = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_conditions = city_weather["weather"][0]["description"]
        #parsing array reference: https://devqa.io/python-parse-json/
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data2.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                           "Current Description": city_conditions,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | lagoa
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | maarianhamina
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | port hardy
# Processing Record 9 of Set 1 | redding
# Processing Record 10 of Set 1 | waipawa
# Processing Record 11 of Set 1 | praia da vitoria
# Processing Record 12 of Set 1 | meridian
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | geraldton
# Processing Record 17 of Set 1 | buraydah
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | alofi
# Processing Record 21 of Set 1 | petershagen
# Processing Record 22 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | luderitz
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | saint-francois
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | porbandar
# Processing Record 36 of Set 1 | mehamn
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 1 | saint-ambroise
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | laguna
# Processing Record 42 of Set 1 | bara
# Processing Record 43 of Set 1 | akdepe
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | cherskiy
# Processing Record 48 of Set 1 | xuddur
# Processing Record 49 of Set 1 | pacific grove
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | tara
# Processing Record 3 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 2 | margate
# Processing Record 5 of Set 2 | muzhi
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | puerto escondido
# Processing Record 8 of Set 2 | ostrovnoy
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | killybegs
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | phangnga
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | siteki
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | rio grande
# Processing Record 20 of Set 2 | sarakhs
# Processing Record 21 of Set 2 | zlynka
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | barcelos
# Processing Record 24 of Set 2 | viedma
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | husavik
# Processing Record 27 of Set 2 | yasnyy
# Processing Record 28 of Set 2 | hami
# Processing Record 29 of Set 2 | lorengau
# Processing Record 30 of Set 2 | katsuura
# Processing Record 31 of Set 2 | tazovskiy
# Processing Record 32 of Set 2 | acapulco
# Processing Record 33 of Set 2 | kumylzhenskaya
# Processing Record 34 of Set 2 | coquimbo
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | manakara
# Processing Record 37 of Set 2 | vaitape
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | nkowakowa
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 | taywarah
# Processing Record 45 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 2 | kishi
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | kununurra
# Processing Record 49 of Set 2 | norman wells
# Processing Record 50 of Set 2 | mayo
# Processing Record 1 of Set 3 | san patricio
# Processing Record 2 of Set 3 | komsomolskiy
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | malpe
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | nabire
# Processing Record 7 of Set 3 | vibo valentia
# Processing Record 8 of Set 3 | hudson bay
# Processing Record 9 of Set 3 | sur
# Processing Record 10 of Set 3 | lexington
# Processing Record 11 of Set 3 | san rafael
# Processing Record 12 of Set 3 | totma
# Processing Record 13 of Set 3 | banjar
# Processing Record 14 of Set 3 | ust-kalmanka
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | nanortalik
# Processing Record 18 of Set 3 | aitape
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | lakes entrance
# Processing Record 21 of Set 3 | samarai
# Processing Record 22 of Set 3 | pithiviers
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | nanzhang
# Processing Record 26 of Set 3 | namibe
# Processing Record 27 of Set 3 | navsari
# Processing Record 28 of Set 3 | balabac
# Processing Record 29 of Set 3 | paamiut
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | hofn
# Processing Record 32 of Set 3 | dingle
# Processing Record 33 of Set 3 | iqaluit
# Processing Record 34 of Set 3 | hanyang
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | korla
# Processing Record 37 of Set 3 | muniz freire
# Processing Record 38 of Set 3 | half moon bay
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | richards bay
# Processing Record 41 of Set 3 | arman
# Processing Record 42 of Set 3 | yuli
# Processing Record 43 of Set 3 | sao joao da barra
# Processing Record 44 of Set 3 | canitas
# City not found. Skipping...
# Processing Record 45 of Set 3 | lazarev
# Processing Record 46 of Set 3 | pontianak
# Processing Record 47 of Set 3 | koslan
# Processing Record 48 of Set 3 | iquique
# Processing Record 49 of Set 3 | cockburn town
# Processing Record 50 of Set 3 | port-gentil
# Processing Record 1 of Set 4 | celestun
# Processing Record 2 of Set 4 | teya
# Processing Record 3 of Set 4 | roald
# Processing Record 4 of Set 4 | srivardhan
# Processing Record 5 of Set 4 | ikovka
# Processing Record 6 of Set 4 | auki
# Processing Record 7 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 4 | la ronge
# Processing Record 9 of Set 4 | ron phibun
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | na klang
# Processing Record 12 of Set 4 | kushima
# Processing Record 13 of Set 4 | hereford
# Processing Record 14 of Set 4 | mlawa
# Processing Record 15 of Set 4 | raga
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | denpasar
# Processing Record 20 of Set 4 | pronsk
# Processing Record 21 of Set 4 | marawi
# Processing Record 22 of Set 4 | kysyl-syr
# Processing Record 23 of Set 4 | meulaboh
# Processing Record 24 of Set 4 | nata
# Processing Record 25 of Set 4 | palana
# Processing Record 26 of Set 4 | davila
# Processing Record 27 of Set 4 | motygino
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 4 | valpacos
# Processing Record 31 of Set 4 | svetlogorsk
# Processing Record 32 of Set 4 | sederot
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | formosa do rio preto
# Processing Record 35 of Set 4 | rundu
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | homer
# Processing Record 38 of Set 4 | bud
# Processing Record 39 of Set 4 | santa lucia
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | balsas
# Processing Record 42 of Set 4 | aripuana
# Processing Record 43 of Set 4 | altay
# Processing Record 44 of Set 4 | mombaca
# Processing Record 45 of Set 4 | kronshagen
# Processing Record 46 of Set 4 | buenos aires
# Processing Record 47 of Set 4 | calatayud
# Processing Record 48 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 49 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 4 | boa vista
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | vestmanna
# Processing Record 3 of Set 5 | neepawa
# Processing Record 4 of Set 5 | marsh harbour
# Processing Record 5 of Set 5 | wielun
# Processing Record 6 of Set 5 | simplicio mendes
# Processing Record 7 of Set 5 | peniche
# Processing Record 8 of Set 5 | lengshuitan
# Processing Record 9 of Set 5 | bathsheba
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | gazanjyk
# Processing Record 12 of Set 5 | fairbanks
# Processing Record 13 of Set 5 | sri aman
# Processing Record 14 of Set 5 | mahibadhoo
# Processing Record 15 of Set 5 | jumla
# Processing Record 16 of Set 5 | itacoatiara
# Processing Record 17 of Set 5 | iracoubo
# Processing Record 18 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 19 of Set 5 | inhambane
# Processing Record 20 of Set 5 | puerto carreno
# Processing Record 21 of Set 5 | damghan
# Processing Record 22 of Set 5 | lunenburg
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | abeche
# Processing Record 25 of Set 5 | hasaki
# Processing Record 26 of Set 5 | yate
# Processing Record 27 of Set 5 | sayabec
# City not found. Skipping...
# Processing Record 28 of Set 5 | semey
# Processing Record 29 of Set 5 | buta
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | amahai
# Processing Record 32 of Set 5 | udachnyy
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | verkhnevilyuysk
# Processing Record 35 of Set 5 | broome
# Processing Record 36 of Set 5 | saint-pierre
# Processing Record 37 of Set 5 | sikea
# City not found. Skipping...
# Processing Record 38 of Set 5 | ugoofaaru
# Processing Record 39 of Set 5 | neiafu
# Processing Record 40 of Set 5 | yerbogachen
# Processing Record 41 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | trat
# Processing Record 44 of Set 5 | saint-philippe
# Processing Record 45 of Set 5 | esil
# Processing Record 46 of Set 5 | castro
# Processing Record 47 of Set 5 | connersville
# Processing Record 48 of Set 5 | marienburg
# Processing Record 49 of Set 5 | mokhsogollokh
# Processing Record 50 of Set 5 | barranca
# Processing Record 1 of Set 6 | nsanje
# Processing Record 2 of Set 6 | cayenne
# Processing Record 3 of Set 6 | ust-omchug
# Processing Record 4 of Set 6 | arraial do cabo
# Processing Record 5 of Set 6 | bandarbeyla
# Processing Record 6 of Set 6 | marzuq
# Processing Record 7 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 6 | hay river
# Processing Record 9 of Set 6 | puerto narino
# Processing Record 10 of Set 6 | lensk
# Processing Record 11 of Set 6 | rawson
# Processing Record 12 of Set 6 | portland
# Processing Record 13 of Set 6 | filadelfia
# Processing Record 14 of Set 6 | vangaindrano
# Processing Record 15 of Set 6 | sitka
# Processing Record 16 of Set 6 | never
# Processing Record 17 of Set 6 | marabba
# Processing Record 18 of Set 6 | batagay-alyta
# Processing Record 19 of Set 6 | saint anthony
# Processing Record 20 of Set 6 | coruripe
# Processing Record 21 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 22 of Set 6 | kantabanji
# Processing Record 23 of Set 6 | mosquera
# Processing Record 24 of Set 6 | faanui
# Processing Record 25 of Set 6 | vao
# Processing Record 26 of Set 6 | taoudenni
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | naryan-mar
# Processing Record 29 of Set 6 | yubari
# Processing Record 30 of Set 6 | alyangula
# Processing Record 31 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 6 | urusha
# Processing Record 33 of Set 6 | rafai
# Processing Record 34 of Set 6 | melo
# Processing Record 35 of Set 6 | karasjok
# Processing Record 36 of Set 6 | gat
# Processing Record 37 of Set 6 | campoverde
# Processing Record 38 of Set 6 | kloulklubed
# Processing Record 39 of Set 6 | port hedland
# Processing Record 40 of Set 6 | kampot
# Processing Record 41 of Set 6 | maragogi
# Processing Record 42 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 6 | yar-sale
# Processing Record 44 of Set 6 | kautokeino
# Processing Record 45 of Set 6 | benjamin constant
# Processing Record 46 of Set 6 | bilibino
# Processing Record 47 of Set 6 | porto novo
# Processing Record 48 of Set 6 | tecoanapa
# Processing Record 49 of Set 6 | matara
# Processing Record 50 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 1 of Set 7 | grindavik
# Processing Record 2 of Set 7 | ihosy
# Processing Record 3 of Set 7 | eirunepe
# Processing Record 4 of Set 7 | traverse city
# Processing Record 5 of Set 7 | ishigaki
# Processing Record 6 of Set 7 | sinop
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | sirnak
# Processing Record 9 of Set 7 | cabo san lucas
# Processing Record 10 of Set 7 | dawei
# Processing Record 11 of Set 7 | turukhansk
# Processing Record 12 of Set 7 | byron bay
# Processing Record 13 of Set 7 | kostomuksha
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | wuchi
# Processing Record 16 of Set 7 | tinaquillo
# Processing Record 17 of Set 7 | ketchikan
# Processing Record 18 of Set 7 | gao
# Processing Record 19 of Set 7 | north bend
# Processing Record 20 of Set 7 | akusha
# Processing Record 21 of Set 7 | pionerskiy
# Processing Record 22 of Set 7 | kashan
# Processing Record 23 of Set 7 | sawtell
# Processing Record 24 of Set 7 | buala
# Processing Record 25 of Set 7 | tocopilla
# Processing Record 26 of Set 7 | amapa
# Processing Record 27 of Set 7 | sambava
# Processing Record 28 of Set 7 | bilma
# Processing Record 29 of Set 7 | sault sainte marie
# Processing Record 30 of Set 7 | lashio
# Processing Record 31 of Set 7 | goundam
# Processing Record 32 of Set 7 | plouzane
# Processing Record 33 of Set 7 | walvis bay
# Processing Record 34 of Set 7 | shingu
# Processing Record 35 of Set 7 | vredendal
# Processing Record 36 of Set 7 | goderich
# Processing Record 37 of Set 7 | beringovskiy
# Processing Record 38 of Set 7 | qesarya
# Processing Record 39 of Set 7 | maniitsoq
# Processing Record 40 of Set 7 | maralal
# Processing Record 41 of Set 7 | chinchani
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | svetlaya
# Processing Record 44 of Set 7 | iwanai
# Processing Record 45 of Set 7 | alekseyevka
# Processing Record 46 of Set 7 | cairns
# Processing Record 47 of Set 7 | sibolga
# Processing Record 48 of Set 7 | hambantota
# Processing Record 49 of Set 7 | kilinochchi
# Processing Record 50 of Set 7 | kefamenanu
# Processing Record 1 of Set 8 | sinegorye
# Processing Record 2 of Set 8 | saldanha
# Processing Record 3 of Set 8 | bengkulu
# Processing Record 4 of Set 8 | namatanai
# Processing Record 5 of Set 8 | rimos
# City not found. Skipping...
# Processing Record 6 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 8 | tukrah
# Processing Record 8 of Set 8 | pitimbu
# Processing Record 9 of Set 8 | ayan
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | alagir
# Processing Record 12 of Set 8 | atbasar
# Processing Record 13 of Set 8 | west bay
# Processing Record 14 of Set 8 | talnakh
# Processing Record 15 of Set 8 | henties bay
# Processing Record 16 of Set 8 | ngaoundere
# Processing Record 17 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 8 | concordia
# Processing Record 19 of Set 8 | saravan
# Processing Record 20 of Set 8 | dicabisagan
# Processing Record 21 of Set 8 | tigil
# Processing Record 22 of Set 8 | te anau
# Processing Record 23 of Set 8 | dolores
# Processing Record 24 of Set 8 | salalah
# Processing Record 25 of Set 8 | bollnas
# Processing Record 26 of Set 8 | poum
# Processing Record 27 of Set 8 | belaya gora
# Processing Record 28 of Set 8 | esperance
# Processing Record 29 of Set 8 | isangel
# Processing Record 30 of Set 8 | sorland
# Processing Record 31 of Set 8 | bajram curri
# Processing Record 32 of Set 8 | sinnamary
# Processing Record 33 of Set 8 | provideniya
# Processing Record 34 of Set 8 | gwanda
# Processing Record 35 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 8 | batemans bay
# Processing Record 37 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 8 | mount gambier
# Processing Record 39 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 8 | tramore
# Processing Record 41 of Set 8 | alaca
# Processing Record 42 of Set 8 | paramonga
# Processing Record 43 of Set 8 | souillac
# Processing Record 44 of Set 8 | sechura
# Processing Record 45 of Set 8 | amangarh
# Processing Record 46 of Set 8 | los palacios
# Processing Record 47 of Set 8 | asau
# Processing Record 48 of Set 8 | omboue
# Processing Record 49 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 8 | mbandaka
# Processing Record 1 of Set 9 | san vicente
# Processing Record 2 of Set 9 | tabou
# Processing Record 3 of Set 9 | broken hill
# Processing Record 4 of Set 9 | adrar
# Processing Record 5 of Set 9 | fatezh
# Processing Record 6 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 7 of Set 9 | smithers
# Processing Record 8 of Set 9 | humberto de campos
# Processing Record 9 of Set 9 | cidreira
# Processing Record 10 of Set 9 | constitucion
# Processing Record 11 of Set 9 | jalu
# Processing Record 12 of Set 9 | haines junction
# Processing Record 13 of Set 9 | vung tau
# Processing Record 14 of Set 9 | madimba
# Processing Record 15 of Set 9 | maceio
# Processing Record 16 of Set 9 | zharkent
# Processing Record 17 of Set 9 | dori
# Processing Record 18 of Set 9 | labuhan
# Processing Record 19 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 9 | rosarito
# Processing Record 21 of Set 9 | bantou
# Processing Record 22 of Set 9 | castillo de teayo
# Processing Record 23 of Set 9 | vestmannaeyjar
# Processing Record 24 of Set 9 | virginia beach
# Processing Record 25 of Set 9 | kaspiyskiy
# Processing Record 26 of Set 9 | coihaique
# Processing Record 27 of Set 9 | lusambo
# Processing Record 28 of Set 9 | chara
# Processing Record 29 of Set 9 | kieta
# Processing Record 30 of Set 9 | kaeo
# Processing Record 31 of Set 9 | aklavik
# Processing Record 32 of Set 9 | ust-barguzin
# Processing Record 33 of Set 9 | hithadhoo
# Processing Record 34 of Set 9 | saskylakh
# Processing Record 35 of Set 9 | vigrestad
# Processing Record 36 of Set 9 | nouadhibou
# Processing Record 37 of Set 9 | maneromango
# Processing Record 38 of Set 9 | hurghada
# Processing Record 39 of Set 9 | kaitangata
# Processing Record 40 of Set 9 | nyurba
# Processing Record 41 of Set 9 | xam nua
# Processing Record 42 of Set 9 | cabedelo
# Processing Record 43 of Set 9 | biaora
# Processing Record 44 of Set 9 | bayeux
# Processing Record 45 of Set 9 | hovd
# Processing Record 46 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 9 | ballina
# Processing Record 48 of Set 9 | zhigansk
# Processing Record 49 of Set 9 | tiksi
# Processing Record 50 of Set 9 | warin chamrap
# Processing Record 1 of Set 10 | kampong thum
# Processing Record 2 of Set 10 | glace bay
# Processing Record 3 of Set 10 | rodos
# Processing Record 4 of Set 10 | wabag
# Processing Record 5 of Set 10 | umm lajj
# Processing Record 6 of Set 10 | guayaramerin
# Processing Record 7 of Set 10 | anadyr
# Processing Record 8 of Set 10 | soto la marina
# Processing Record 9 of Set 10 | tirumullaivasal
# Processing Record 10 of Set 10 | muisne
# Processing Record 11 of Set 10 | fort nelson
# Processing Record 12 of Set 10 | cornwall
# Processing Record 13 of Set 10 | nogliki
# Processing Record 14 of Set 10 | wichita falls
# Processing Record 15 of Set 10 | jizan
# Processing Record 16 of Set 10 | kidal
# Processing Record 17 of Set 10 | ilula
# Processing Record 18 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 10 | kamenka
# Processing Record 20 of Set 10 | poitiers
# Processing Record 21 of Set 10 | tekari
# Processing Record 22 of Set 10 | san cristobal
# Processing Record 23 of Set 10 | espanola
# Processing Record 24 of Set 10 | sturgeon falls
# Processing Record 25 of Set 10 | guerrero negro
# Processing Record 26 of Set 10 | hualmay
# Processing Record 27 of Set 10 | dombarovskiy
# Processing Record 28 of Set 10 | vila franca do campo
# Processing Record 29 of Set 10 | santa fe
# Processing Record 30 of Set 10 | bronnoysund
# Processing Record 31 of Set 10 | macaracas
# Processing Record 32 of Set 10 | manzhouli
# Processing Record 33 of Set 10 | galveston
# Processing Record 34 of Set 10 | lere
# Processing Record 35 of Set 10 | songea
# Processing Record 36 of Set 10 | kalevala
# Processing Record 37 of Set 10 | shache
# Processing Record 38 of Set 10 | outlook
# Processing Record 39 of Set 10 | srednekolymsk
# Processing Record 40 of Set 10 | hammerfest
# Processing Record 41 of Set 10 | chapais
# Processing Record 42 of Set 10 | ambon
# Processing Record 43 of Set 10 | provins
# Processing Record 44 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 10 | sao jose de ribamar
# Processing Record 46 of Set 10 | zarand
# Processing Record 47 of Set 10 | usinsk
# Processing Record 48 of Set 10 | usolye-sibirskoye
# Processing Record 49 of Set 10 | shubarshi
# Processing Record 50 of Set 10 | harriston
# Processing Record 1 of Set 11 | leningradskiy
# Processing Record 2 of Set 11 | mutsu
# Processing Record 3 of Set 11 | lubango
# Processing Record 4 of Set 11 | umtata
# Processing Record 5 of Set 11 | clyde river
# Processing Record 6 of Set 11 | kamareddi
# Processing Record 7 of Set 11 | camana
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | dalvik
# Processing Record 10 of Set 11 | starkville
# Processing Record 11 of Set 11 | arkansas city
# Processing Record 12 of Set 11 | padang
# Processing Record 13 of Set 11 | yulara
# Processing Record 14 of Set 11 | karratha
# Processing Record 15 of Set 11 | carauari
# Processing Record 16 of Set 11 | lancaster
# Processing Record 17 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 11 | yunyang
# Processing Record 19 of Set 11 | tavda
# Processing Record 20 of Set 11 | port lincoln
# Processing Record 21 of Set 11 | siavonga
# Processing Record 22 of Set 11 | quatre cocos
# Processing Record 23 of Set 11 | verkhnyaya maksakovka
# Processing Record 24 of Set 11 | ondjiva
# Processing Record 25 of Set 11 | ocos
# Processing Record 26 of Set 11 | kodinsk
# Processing Record 27 of Set 11 | touros
# Processing Record 28 of Set 11 | macas
# Processing Record 29 of Set 11 | mackenzie
# Processing Record 30 of Set 11 | atka
# City not found. Skipping...
# Processing Record 31 of Set 11 | vardo
# Processing Record 32 of Set 11 | sao felix do xingu
# Processing Record 33 of Set 11 | dondo
# Processing Record 34 of Set 11 | alice springs
# Processing Record 35 of Set 11 | cabildo
# Processing Record 36 of Set 11 | marsala
# Processing Record 37 of Set 11 | mahajanga
# Processing Record 38 of Set 11 | birjand
# Processing Record 39 of Set 11 | paris
# Processing Record 40 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 11 | suntar
# Processing Record 42 of Set 11 | biltine
# Processing Record 43 of Set 11 | muros
# Processing Record 44 of Set 11 | rabo de peixe
# Processing Record 45 of Set 11 | the valley
# Processing Record 46 of Set 11 | raikot
# Processing Record 47 of Set 11 | magadan
# Processing Record 48 of Set 11 | dobrinka
# Processing Record 49 of Set 11 | havoysund
# Processing Record 50 of Set 11 | santo antonio do ica
# Processing Record 1 of Set 12 | ajdabiya
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | fayaoue
# Processing Record 4 of Set 12 | comodoro rivadavia
# Processing Record 5 of Set 12 | kshenskiy
# Processing Record 6 of Set 12 | khingansk
# Processing Record 7 of Set 12 | robertsport
# Processing Record 8 of Set 12 | pevek
# Processing Record 9 of Set 12 | kungurtug
# Processing Record 10 of Set 12 | port keats
# Processing Record 11 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 12 | arlit
# Processing Record 14 of Set 12 | zhezkazgan
# Processing Record 15 of Set 12 | nizhniy odes
# Processing Record 16 of Set 12 | agirish
# Processing Record 17 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 12 | hope
# Processing Record 19 of Set 12 | havre-saint-pierre
# Processing Record 20 of Set 12 | zeya
# Processing Record 21 of Set 12 | ascension
# Processing Record 22 of Set 12 | guanica
# Processing Record 23 of Set 12 | xiongyue
# Processing Record 24 of Set 12 | ust-kishert
# Processing Record 25 of Set 12 | singleton
# Processing Record 26 of Set 12 | dwarahat
# Processing Record 27 of Set 12 | noumea
# Processing Record 28 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 12 | weligama
# Processing Record 31 of Set 12 | kapuskasing
# Processing Record 32 of Set 12 | guajara
# Processing Record 33 of Set 12 | swellendam
# Processing Record 34 of Set 12 | konstantinovka
# Processing Record 35 of Set 12 | launceston
# Processing Record 36 of Set 12 | truth or consequences
# Processing Record 37 of Set 12 | cam ranh
# Processing Record 38 of Set 12 | warrington
# Processing Record 39 of Set 12 | burns lake
# Processing Record 40 of Set 12 | mildura
# Processing Record 41 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 42 of Set 12 | hailar
# Processing Record 43 of Set 12 | jingdezhen
# Processing Record 44 of Set 12 | maldonado
# Processing Record 45 of Set 12 | qaqortoq
# Processing Record 46 of Set 12 | tshikapa
# Processing Record 47 of Set 12 | ubinskoye
# Processing Record 48 of Set 12 | kalabo
# Processing Record 49 of Set 12 | lewiston
# Processing Record 50 of Set 12 | tuatapere
# Processing Record 1 of Set 13 | vostok
# Processing Record 2 of Set 13 | santa marta
# Processing Record 3 of Set 13 | mao
# Processing Record 4 of Set 13 | christchurch
# Processing Record 5 of Set 13 | takoradi
# Processing Record 6 of Set 13 | iquitos
# Processing Record 7 of Set 13 | belmonte
# Processing Record 8 of Set 13 | tome-acu
# City not found. Skipping...
# Processing Record 9 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 13 | kirakira
# Processing Record 12 of Set 13 | chabahar
# Processing Record 13 of Set 13 | phan thiet
# Processing Record 14 of Set 13 | yumen
# Processing Record 15 of Set 13 | beloha
# Processing Record 16 of Set 13 | cacoal
# Processing Record 17 of Set 13 | huaihua
# Processing Record 18 of Set 13 | coahuayana
# Processing Record 19 of Set 13 | cervo
# Processing Record 20 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 21 of Set 13 | terney
# Processing Record 22 of Set 13 | ambulu
# Processing Record 23 of Set 13 | belyy yar
# Processing Record 24 of Set 13 | tokur
# Processing Record 25 of Set 13 | okha
# Processing Record 26 of Set 13 | tucumcari
# Processing Record 27 of Set 13 | ilhabela
# Processing Record 28 of Set 13 | mbuyapey
# Processing Record 29 of Set 13 | harrison
# Processing Record 30 of Set 13 | college
# Processing Record 31 of Set 13 | odweyne
# Processing Record 32 of Set 13 | mahebourg
# Processing Record 33 of Set 13 | bam
# Processing Record 34 of Set 13 | prince rupert
# Processing Record 35 of Set 13 | graaff-reinet
# Processing Record 36 of Set 13 | corrales
# Processing Record 37 of Set 13 | misrikh
# Processing Record 38 of Set 13 | imbituba
# Processing Record 39 of Set 13 | karauli
# Processing Record 40 of Set 13 | wanning
# Processing Record 41 of Set 13 | basoko
# Processing Record 42 of Set 13 | behshahr
# Processing Record 43 of Set 13 | shitkino
# Processing Record 44 of Set 13 | bemidji
# Processing Record 45 of Set 13 | marsa matruh
# Processing Record 46 of Set 13 | muravlenko
# Processing Record 47 of Set 13 | port augusta
# Processing Record 48 of Set 13 | jiujiang
# Processing Record 49 of Set 13 | najran
# Processing Record 50 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 14 | kismayo
# Processing Record 2 of Set 14 | mandalgovi
# Processing Record 3 of Set 14 | rieti
# Processing Record 4 of Set 14 | mega
# Processing Record 5 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 14 | baghdad
# Processing Record 7 of Set 14 | praya
# Processing Record 8 of Set 14 | nakapiripirit
# Processing Record 9 of Set 14 | auburn
# Processing Record 10 of Set 14 | idritsa
# Processing Record 11 of Set 14 | vila velha
# Processing Record 12 of Set 14 | kandrian
# Processing Record 13 of Set 14 | deputatskiy
# Processing Record 14 of Set 14 | yermish
# Processing Record 15 of Set 14 | majene
# Processing Record 16 of Set 14 | siuri
# Processing Record 17 of Set 14 | russellville
# Processing Record 18 of Set 14 | novochernorechenskiy
# Processing Record 19 of Set 14 | baoshan
# Processing Record 20 of Set 14 | sidmouth
# Processing Record 21 of Set 14 | viytivka
# Processing Record 22 of Set 14 | manokwari
# Processing Record 23 of Set 14 | mackay
# Processing Record 24 of Set 14 | brae
# Processing Record 25 of Set 14 | novoagansk
# Processing Record 26 of Set 14 | neuquen
# Processing Record 27 of Set 14 | fairhaven
# Processing Record 28 of Set 14 | carutapera
# Processing Record 29 of Set 14 | bambanglipuro
# Processing Record 30 of Set 14 | weymouth
# Processing Record 31 of Set 14 | general roca
# Processing Record 32 of Set 14 | baiyin
# Processing Record 33 of Set 14 | liku
# Processing Record 34 of Set 14 | mitu
# Processing Record 35 of Set 14 | tilichiki
# Processing Record 36 of Set 14 | chamba
# Processing Record 37 of Set 14 | manzanillo
# Processing Record 38 of Set 14 | nemuro
# Processing Record 39 of Set 14 | pandaria
# Processing Record 40 of Set 14 | kerema
# Processing Record 41 of Set 14 | haapiti
# Processing Record 42 of Set 14 | kadaya
# Processing Record 43 of Set 14 | shaowu
# Processing Record 44 of Set 14 | charters towers
# Processing Record 45 of Set 14 | filingue
# Processing Record 46 of Set 14 | zlobin
# Processing Record 47 of Set 14 | dhidhdhoo
# Processing Record 48 of Set 14 | manadhoo
# Processing Record 49 of Set 14 | sao desiderio
# Processing Record 50 of Set 14 | lima
# Processing Record 1 of Set 15 | halifax
# Processing Record 2 of Set 15 | radcliff
# Processing Record 3 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 15 | lata
# Processing Record 6 of Set 15 | zaysan
# Processing Record 7 of Set 15 | derbent
# Processing Record 8 of Set 15 | zlocieniec
# Processing Record 9 of Set 15 | sobolevo
# Processing Record 10 of Set 15 | dobrokoz
# Processing Record 11 of Set 15 | hailey
# Processing Record 12 of Set 15 | mirnyy
# Processing Record 13 of Set 15 | carmarthen
# Processing Record 14 of Set 15 | ardatov
# Processing Record 15 of Set 15 | mwense
# Processing Record 16 of Set 15 | dibaya
# City not found. Skipping...
# Processing Record 17 of Set 15 | jinxiang
# Processing Record 18 of Set 15 | marigot
# Processing Record 19 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 15 | phuket
# Processing Record 21 of Set 15 | tafo
# Processing Record 22 of Set 15 | yongchang
# Processing Record 23 of Set 15 | podzvizd
# Processing Record 24 of Set 15 | okoneshnikovo
# Processing Record 25 of Set 15 | pak phanang
# Processing Record 26 of Set 15 | nishihara
# Processing Record 27 of Set 15 | puerto leguizamo
# Processing Record 28 of Set 15 | monterey
# Processing Record 29 of Set 15 | nguruka
# Processing Record 30 of Set 15 | cap malheureux
# Processing Record 31 of Set 15 | luzhou
# Processing Record 32 of Set 15 | selfoss
# Processing Record 33 of Set 15 | sisimiut
# Processing Record 34 of Set 15 | mananara
# Processing Record 35 of Set 15 | tabat
# Processing Record 36 of Set 15 | burnie
# Processing Record 37 of Set 15 | jijiga
# Processing Record 38 of Set 15 | khandyga
# Processing Record 39 of Set 15 | mogzon
# Processing Record 40 of Set 15 | san quintin
# Processing Record 41 of Set 15 | atar
# Processing Record 42 of Set 15 | khani
# Processing Record 43 of Set 15 | lubao
# Processing Record 44 of Set 15 | yarada
# Processing Record 45 of Set 15 | berbera
# Processing Record 46 of Set 15 | bukama
# Processing Record 47 of Set 15 | dunedin
# Processing Record 48 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 15 | whitehorse
# Processing Record 50 of Set 15 | mafinga
# Processing Record 1 of Set 16 | emilio carranza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data2))
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_sub_df = pd.DataFrame(city_data2)
city_data_sub_df.head(10)
# Out:
#                City      Lat       Lng Current Description  Max Temp  \
# 0           Rikitea -23.1203 -134.9692       broken clouds     73.33
# 1        Chokurdakh  70.6333  147.9167     overcast clouds      6.19
# 2             Lagoa  39.0500  -27.9833          light rain     62.78
# 3    Ribeira Grande  38.5167  -28.7000     overcast clouds     61.77
# 4     Maarianhamina  60.0973   19.9348     overcast clouds     51.66
# 5             Kapaa  22.0752 -159.3190           clear sky     84.52
# 6        Port Hardy  50.6996 -127.4199       broken clouds     48.38
# 7           Redding  40.5865 -122.3917           clear sky     72.63
# 8           Waipawa -41.4122  175.5153       broken clouds     60.53
# 9  Praia Da Vitoria  38.7333  -27.0667    scattered clouds     60.76
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        74          62       16.98      PF
# 1        97         100        2.68      RU
# 2        68          21       22.39      PT
# 3        72          88        3.00      PT
# 4       100         100        6.91      AX
# 5        72           0       17.27      US
# 6        81          75        2.30      CA
# 7        27           0        4.61      US
# 8        59          59       15.19      NZ
# 9        84          39       12.71      PT

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_sub_df = city_data_sub_df[new_column_order]
city_data_sub_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Rikitea      PF -23.1203 -134.9692     73.33        74
# 1        Chokurdakh      RU  70.6333  147.9167      6.19        97
# 2             Lagoa      PT  39.0500  -27.9833     62.78        68
# 3    Ribeira Grande      PT  38.5167  -28.7000     61.77        72
# 4     Maarianhamina      AX  60.0973   19.9348     51.66       100
# 5             Kapaa      US  22.0752 -159.3190     84.52        72
# 6        Port Hardy      CA  50.6996 -127.4199     48.38        81
# 7           Redding      US  40.5865 -122.3917     72.63        27
# 8           Waipawa      NZ -41.4122  175.5153     60.53        59
# 9  Praia Da Vitoria      PT  38.7333  -27.0667     60.76        84
#
#    Cloudiness  Wind Speed Current Description
# 0          62       16.98       broken clouds
# 1         100        2.68     overcast clouds
# 2          21       22.39          light rain
# 3          88        3.00     overcast clouds
# 4         100        6.91     overcast clouds
# 5           0       17.27           clear sky
# 6          75        2.30       broken clouds
# 7           0        4.61           clear sky
# 8          59       15.19       broken clouds
# 9          39       12.71    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_sub_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_sub_df["Lat"]
max_temps = city_data_sub_df["Max Temp"]
humidity = city_data_sub_df["Humidity"]
cloudiness = city_data_sub_df["Cloudiness"]
wind_speed = city_data_sub_df["Wind Speed"]
